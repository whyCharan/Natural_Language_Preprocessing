# %% [markdown]
# # 1. Preprocessing and Cleaning
# # 2. Train Test Split
# # 3. Bow and TF-Idf (sentences --> vectors) {preventing data Leakage}
# # 4. Trained our Models

# %%
import pandas as pd

# %%
messages = pd.read_csv('./SMSSpamCollection.txt',sep='\t',names=['label','message'])

# %%
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %%
import re 
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chara\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
corpus = [] 

for i in range(0,len(messages)):
    review = re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %% [markdown]
# # train test split

# %%
## out features

y = pd.get_dummies(messages['label'], dtype=int)
y = y.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(corpus,y,test_size=0.2)

# %% [markdown]
# ## Create Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_features=2500,ngram_range=(1,2))

# %%
x_train_b = cv.fit_transform(x_train).toarray()
x_test_b = cv.transform(x_test).toarray()

# %%
cv.vocabulary_
# Out:
# {'hungri': np.int64(998),
#  'gay': np.int64(778),
#  'guy': np.int64(900),
#  'feel': np.int64(689),
#  'call': np.int64(247),
#  'min': np.int64(1299),
#  'stop': np.int64(1993),
#  'text': np.int64(2080),
#  'call min': np.int64(259),
#  'min stop': np.int64(1302),
#  'stop text': np.int64(1999),
#  'text call': np.int64(2082),
#  'pick': np.int64(1572),
#  'anoth': np.int64(70),
#  'th': np.int64(2091),
#  'done': np.int64(557),
#  'ok': np.int64(1473),
#  'thanx': np.int64(2097),
#  'gd': np.int64(783),
#  'nite': np.int64(1426),
#  'ok thanx': np.int64(1482),
#  'still': np.int64(1986),
#  'get': np.int64(789),
#  'good': np.int64(841),
#  'loverboy': np.int64(1220),
#  'keep': np.int64(1077),
#  'come': np.int64(388),
#  'queen': np.int64(1672),
#  'hmmm': np.int64(960),
#  'ach': np.int64(15),
#  'speak': np.int64(1958),
#  'miss': np.int64(1313),
#  'cool': np.int64(429),
#  'see': np.int64(1819),
#  'ya': np.int64(2463),
#  'see ya': np.int64(1826),
#  'went': np.int64(2377),
#  'attend': np.int64(113),
#  'two': np.int64(2211),
#  'round': np.int64(1772),
#  'today': np.int64(2147),
#  'reach': np.int64(1693),
#  'home': np.int64(970),
#  'reach home': np.int64(1695),
#  'movi': np.int64(1361),
#  'theatr': np.int64(2100),
#  'go': np.int64(812),
#  'watch': np.int64(2342),
#  'unlimit': np.int64(2239),
#  'pay': np.int64(1545),
#  'go watch': np.int64(830),
#  'best': np.int64(164),
#  'line': np.int64(1167),
#  'said': np.int64(1786),
#  'love': np.int64(1208),
#  'wait': np.int64(2313),
#  'till': np.int64(2126),
#  'day': np.int64(491),
#  'forget': np.int64(727),
#  'realiz': np.int64(1703),
#  'cannot': np.int64(286),
#  'gn': np.int64(810),
#  'wait till': np.int64(2316),
#  'aight': np.int64(43),
#  'lemm': np.int64(1147),
#  'know': np.int64(1099),
#  'lemm know': np.int64(1148),
#  'met': np.int64(1294),
#  'choos': np.int64(343),
#  'friend': np.int64(755),
#  'long': np.int64(1191),
#  'world': np.int64(2429),
#  'stand': np.int64(1978),
#  'friendship': np.int64(760),
#  'never': np.int64(1407),
#  'end': np.int64(608),
#  'let': np.int64(1151),
#  'forev': np.int64(726),
#  'gud': np.int64(892),
#  'thinkin': np.int64(2108),
#  'malaria': np.int64(1247),
#  'relax': np.int64(1723),
#  'children': np.int64(340),
#  'cant': np.int64(287),
#  'would': np.int64(2435),
#  'wors': np.int64(2431),
#  'take': np.int64(2054),
#  'enough': np.int64(618),
#  'replac': np.int64(1735),
#  'give': np.int64(804),
#  'med': np.int64(1276),
#  'vomit': np.int64(2305),
#  'self': np.int64(1832),
#  'limit': np.int64(1166),
#  'ill': np.int64(1012),
#  'mean': np.int64(1274),
#  'complet': np.int64(401),
#  'like': np.int64(1161),
#  'bad': np.int64(135),
#  'dat': np.int64(488),
#  'gal': np.int64(773),
#  'wat': np.int64(2338),
#  'hand': np.int64(911),
#  'phone': np.int64(1565),
#  'chat': np.int64(329),
#  'wit': np.int64(2408),
#  'told': np.int64(2159),
#  'earlier': np.int64(589),
#  'princess': np.int64(1646),
#  'number': np.int64(1453),
#  'ur': np.int64(2248),
#  'award': np.int64(122),
#  'citi': np.int64(347),
#  'break': np.int64(219),
#  'could': np.int64(438),
#  'win': np.int64(2396),
#  'summer': np.int64(2027),
#  'shop': np.int64(1873),
#  'spree': np.int64(1973),
#  'everi': np.int64(644),
#  'wk': np.int64(2413),
#  'txt': np.int64(2213),
#  'store': np.int64(2002),
#  'tsc': np.int64(2202),
#  'age': np.int64(37),
#  'ur award': np.int64(2249),
#  'shop spree': np.int64(1874),
#  'everi wk': np.int64(648),
#  'wk txt': np.int64(2415),
#  'wonder': np.int64(2422),
#  'okay': np.int64(1483),
#  'uncl': np.int64(2235),
#  'john': np.int64(1059),
#  'thing': np.int64(2102),
#  'nigeria': np.int64(1421),
#  'lt': np.int64(1223),
#  'gt': np.int64(876),
#  'dollar': np.int64(556),
#  'year': np.int64(2481),
#  'sent': np.int64(1847),
#  'plan': np.int64(1590),
#  'back': np.int64(133),
#  'expect': np.int64(661),
#  'anyth': np.int64(76),
#  'practic': np.int64(1634),
#  'someth': np.int64(1939),
#  'let know': np.int64(1152),
#  'lt gt': np.int64(1225),
#  'gt dollar': np.int64(878),
#  'pay back': np.int64(1546),
#  'say': np.int64(1799),
#  'slowli': np.int64(1915),
#  'god': np.int64(832),
#  'amp': np.int64(63),
#  'need': np.int64(1399),
#  'clean': np.int64(358),
#  'heart': np.int64(928),
#  'blood': np.int64(187),
#  'send': np.int64(1836),
#  'ten': np.int64(2074),
#  'special': np.int64(1961),
#  'peopl': np.int64(1549),
#  'miracl': np.int64(1312),
#  'tomorrow': np.int64(2161),
#  'pl': np.int64(1582),
#  'god love': np.int64(833),
#  'heart blood': np.int64(929),
#  'blood send': np.int64(188),
#  'pl pl': np.int64(1586),
#  'tonight': np.int64(2169),
#  'free': np.int64(735),
#  'sir': np.int64(1900),
#  'free call': np.int64(736),
#  'call sir': np.int64(266),
#  'class': np.int64(357),
#  'holla': np.int64(969),
#  'later': np.int64(1121),
#  'run': np.int64(1779),
#  'cross': np.int64(452),
#  'street': np.int64(2007),
#  'urgent': np.int64(2269),
#  'mobil': np.int64(1328),
#  'prize': np.int64(1650),
#  'guarante': np.int64(888),
#  'land': np.int64(1108),
#  'claim': np.int64(348),
#  'valid': np.int64(2284),
#  'hr': np.int64(991),
#  'ppm': np.int64(1630),
#  'urgent mobil': np.int64(2270),
#  'mobil number': np.int64(1335),
#  'number award': np.int64(1454),
#  'award prize': np.int64(126),
#  'prize guarante': np.int64(1653),
#  'guarante call': np.int64(889),
#  'call land': np.int64(256),
#  'land line': np.int64(1109),
#  'line claim': np.int64(1168),
#  'claim valid': np.int64(355),
#  'valid hr': np.int64(2285),
#  'hr ppm': np.int64(992),
#  'way': np.int64(2346),
#  'cup': np.int64(463),
#  'work': np.int64(2426),
#  'bu': np.int64(230),
#  'text way': np.int64(2089),
#  'half': np.int64(908),
#  'hour': np.int64(984),
#  'half hour': np.int64(909),
#  'im': np.int64(1013),
#  'librari': np.int64(1155),
#  'direct': np.int64(541),
#  'access': np.int64(8),
#  'per': np.int64(1550),
#  'msg': np.int64(1367),
#  'get free': np.int64(791),
#  'per day': np.int64(1551),
#  'txt stop': np.int64(2221),
#  'hang': np.int64(913),
#  'brother': np.int64(225),
#  'famili': np.int64(673),
#  'tri': np.int64(2187),
#  'contact': np.int64(416),
#  'repli': np.int64(1736),
#  'offer': np.int64(1463),
#  'video': np.int64(2291),
#  'anytim': np.int64(78),
#  'network': np.int64(1403),
#  'price': np.int64(1643),
#  'rental': np.int64(1732),
#  'camcord': np.int64(274),
#  'tri contact': np.int64(2189),
#  'video phone': np.int64(2292),
#  'phone anytim': np.int64(1566),
#  'anytim network': np.int64(79),
#  'network min': np.int64(1404),
#  'min half': np.int64(1300),
#  'half price': np.int64(910),
#  'price line': np.int64(1644),
#  'line rental': np.int64(1169),
#  'camcord repli': np.int64(275),
#  'repli call': np.int64(1737),
#  'yup': np.int64(2499),
#  'lor': np.int64(1198),
#  'dun': np.int64(581),
#  'wan': np.int64(2320),
#  'anyth lor': np.int64(77),
#  'lor dun': np.int64(1199),
#  'dun wan': np.int64(584),
#  'what': np.int64(2380),
#  'hill': np.int64(953),
#  'hope': np.int64(974),
#  'great': np.int64(865),
#  'fine': np.int64(708),
#  'busi': np.int64(237),
#  'though': np.int64(2112),
#  'hope great': np.int64(977),
#  'great day': np.int64(866),
#  'danc': np.int64(482),
#  'one': np.int64(1488),
#  'time': np.int64(2127),
#  'minut': np.int64(1307),
#  'ur home': np.int64(2257),
#  'gt minut': np.int64(884),
#  'fix': np.int64(714),
#  'spell': np.int64(1965),
#  'sometim': np.int64(1941),
#  'word': np.int64(2424),
#  'figur': np.int64(698),
#  'din': np.int64(538),
#  'wan come': np.int64(2321),
#  'think': np.int64(2103),
#  'cash': np.int64(301),
#  'def': np.int64(511),
#  'readi': np.int64(1699),
#  'still need': np.int64(1989),
#  'need get': np.int64(1400),
#  'buy': np.int64(238),
#  'space': np.int64(1957),
#  'chanc': np.int64(321),
#  'arcad': np.int64(88),
#  'game': np.int64(774),
#  'press': np.int64(1640),
#  'std': np.int64(1984),
#  'wap': np.int64(2335),
#  'charg': np.int64(327),
#  'co': np.int64(366),
#  'uk': np.int64(2229),
#  'term': np.int64(2077),
#  'set': np.int64(1857),
#  'chanc win': np.int64(323),
#  'co uk': np.int64(369),
#  'want': np.int64(2327),
#  'us': np.int64(2275),
#  'awesom': np.int64(129),
#  'deal': np.int64(501),
#  'last': np.int64(1116),
#  'night': np.int64(1422),
#  'yeah': np.int64(2475),
#  'last night': np.int64(1117),
#  'talk': np.int64(2058),
#  'bout': np.int64(207),
#  'earli': np.int64(588),
#  'morn': np.int64(1352),
#  'almost': np.int64(54),
#  'noon': np.int64(1440),
#  'trip': np.int64(2192),
#  'big': np.int64(169),
#  'especi': np.int64(634),
#  'pl give': np.int64(1585),
#  'privat': np.int64(1648),
#  'account': np.int64(11),
#  'statement': np.int64(1981),
#  'show': np.int64(1877),
#  'bonu': np.int64(198),
#  'point': np.int64(1614),
#  'identifi': np.int64(1008),
#  'code': np.int64(370),
#  'expir': np.int64(664),
#  'privat account': np.int64(1649),
#  'account statement': np.int64(14),
#  'statement show': np.int64(1982),
#  'claim call': np.int64(349),
#  'call identifi': np.int64(255),
#  'identifi code': np.int64(1009),
#  'code expir': np.int64(371),
#  'huh': np.int64(996),
#  'hous': np.int64(985),
#  'empti': np.int64(606),
#  'right': np.int64(1757),
#  'dont': np.int64(558),
#  'ask': np.int64(100),
#  'dont know': np.int64(559),
#  'tell': np.int64(2071),
#  'bb': np.int64(148),
#  'longer': np.int64(1193),
#  'comin': np.int64(396),
#  'money': np.int64(1346),
#  'aint': np.int64(44),
#  'messag': np.int64(1290),
#  'name': np.int64(1388),
#  'date': np.int64(489),
#  'lot': np.int64(1203),
#  'that': np.int64(2098),
#  'everyth': np.int64(651),
#  'via': np.int64(2290),
#  'fullonsm': np.int64(766),
#  'com': np.int64(385),
#  'miss sent': np.int64(1318),
#  'sent via': np.int64(1849),
#  'fullonsm com': np.int64(767),
#  'alright': np.int64(57),
#  'hook': np.int64(973),
#  'hear': np.int64(926),
#  'settl': np.int64(1859),
#  'well': np.int64(2372),
#  'da': np.int64(475),
#  'fren': np.int64(752),
#  'meet': np.int64(1277),
#  'also': np.int64(59),
#  'yesterday': np.int64(2487),
#  'til': np.int64(2125),
#  'dear': np.int64(502),
#  'saw': np.int64(1798),
#  'captain': np.int64(292),
#  'parti': np.int64(1539),
#  'grand': np.int64(862),
#  'project': np.int64(1660),
#  'centr': np.int64(318),
#  'boy': np.int64(214),
#  'oh': np.int64(1469),
#  'guid': np.int64(899),
#  'plu': np.int64(1603),
#  'legal': np.int64(1144),
#  'system': np.int64(2052),
#  'slow': np.int64(1914),
#  'gr': np.int64(860),
#  'start': np.int64(1980),
#  'onlin': np.int64(1492),
#  'honey': np.int64(972),
#  'moon': np.int64(1350),
#  'gr day': np.int64(861),
#  'wot': np.int64(2434),
#  'wear': np.int64(2354),
#  'shirt': np.int64(1870),
#  'alway': np.int64(60),
#  'put': np.int64(1669),
#  'pictur': np.int64(1574),
#  'ass': np.int64(107),
#  'facebook': np.int64(669),
#  'open': np.int64(1496),
#  'ever': np.int64(643),
#  'room': np.int64(1769),
#  'hurt': np.int64(1001),
#  'make': np.int64(1242),
#  'make feel': np.int64(1244),
#  'friday': np.int64(754),
#  'leav': np.int64(1140),
#  'except': np.int64(657),
#  'usf': np.int64(2278),
#  'time tonight': np.int64(2133),
#  'shoot': np.int64(1872),
#  'load': np.int64(1179),
#  'get readi': np.int64(793),
#  'girl': np.int64(802),
#  'se': np.int64(1809),
#  'bloodi': np.int64(189),
#  'shit': np.int64(1871),
#  'fuck': np.int64(764),
#  'face': np.int64(668),
#  'rememb': np.int64(1727),
#  'must': np.int64(1383),
#  'decid': np.int64(506),
#  'get back': np.int64(790),
#  'use': np.int64(2276),
#  'hello': np.int64(937),
#  'find': np.int64(704),
#  'job': np.int64(1058),
#  'lazi': np.int64(1132),
#  'toward': np.int64(2179),
#  'net': np.int64(1402),
#  'mummi': np.int64(1376),
#  'boytoy': np.int64(215),
#  'thank': np.int64(2092),
#  'tomo': np.int64(2160),
#  'pussi': np.int64(1668),
#  'perfect': np.int64(1558),
#  'congratul': np.int64(410),
#  'xma': np.int64(2457),
#  'easi': np.int64(591),
#  'bt': np.int64(227),
#  'nation': np.int64(1391),
#  'rate': np.int64(1685),
#  'congratul thank': np.int64(411),
#  'thank good': np.int64(2094),
#  'good friend': np.int64(845),
#  'xma prize': np.int64(2458),
#  'prize claim': np.int64(1652),
#  'claim easi': np.int64(351),
#  'easi call': np.int64(592),
#  'call per': np.int64(263),
#  'per minut': np.int64(1553),
#  'minut bt': np.int64(1308),
#  'bt nation': np.int64(228),
#  'nation rate': np.int64(1392),
#  'wen': np.int64(2375),
#  'lift': np.int64(1158),
#  'knw': np.int64(1101),
#  'wt': np.int64(2442),
#  'real': np.int64(1700),
#  'ye': np.int64(2470),
#  'girlfrnd': np.int64(803),
#  'moral': np.int64(1351),
#  'person': np.int64(1559),
#  'tht': np.int64(2116),
#  'fli': np.int64(717),
#  'lol': np.int64(1187),
#  'yo': np.int64(2492),
#  'beauti': np.int64(153),
#  'ive': np.int64(1047),
#  'seen': np.int64(1829),
#  'babi': np.int64(132),
#  'common': np.int64(397),
#  'address': np.int64(23),
#  'quit': np.int64(1675),
#  'sure': np.int64(2039),
#  'thought': np.int64(2113),
#  'think could': np.int64(2104),
#  'nice': np.int64(1419),
#  'mm': np.int64(1322),
#  'fun': np.int64(768),
#  'promis': np.int64(1661),
#  'even': np.int64(641),
#  'dinner': np.int64(539),
#  'yet': np.int64(2488),
#  'actual': np.int64(20),
#  'nvm': np.int64(1457),
#  'got': np.int64(854),
#  'ish': np.int64(1044),
#  'gt ish': np.int64(880),
#  'oki': np.int64(1484),
#  'want go': np.int64(2329),
#  'lar': np.int64(1115),
#  'si': np.int64(1883),
#  'art': np.int64(98),
#  'co si': np.int64(368),
#  'may': np.int64(1271),
#  'call later': np.int64(258),
#  'worri': np.int64(2430),
#  'hair': np.int64(907),
#  'suppos': np.int64(2037),
#  'town': np.int64(2180),
#  'mind': np.int64(1304),
#  'bedroom': np.int64(157),
#  'sed': np.int64(1817),
#  'sexi': np.int64(1861),
#  'mood': np.int64(1348),
#  'came': np.int64(276),
#  'latr': np.int64(1128),
#  'wid': np.int64(2387),
#  'cake': np.int64(244),
#  'wife': np.int64(2392),
#  'said mind': np.int64(1787),
#  'mind go': np.int64(1305),
#  'go bedroom': np.int64(815),
#  'bedroom minut': np.int64(158),
#  'minut ok': np.int64(1311),
#  'ok sed': np.int64(1480),
#  'sed sexi': np.int64(1818),
#  'sexi mood': np.int64(1863),
#  'mood came': np.int64(1349),
#  'came minut': np.int64(278),
#  'minut latr': np.int64(1309),
#  'latr wid': np.int64(1129),
#  'wid cake': np.int64(2388),
#  'cake wife': np.int64(245),
#  'finish': np.int64(710),
#  'lect': np.int64(1141),
#  'wat time': np.int64(2340),
#  'time finish': np.int64(2129),
#  'much': np.int64(1374),
#  'mu': np.int64(1373),
#  'sort': np.int64(1952),
#  'situat': np.int64(1905),
#  'ah': np.int64(39),
#  'dunno': np.int64(585),
#  'learn': np.int64(1138),
#  'pilat': np.int64(1577),
#  'tuition': np.int64(2206),
#  'go one': np.int64(825),
#  'avail': np.int64(116),
#  'rd': np.int64(1692),
#  'india': np.int64(1024),
#  'record': np.int64(1714),
#  'draw': np.int64(568),
#  'po': np.int64(1609),
#  'box': np.int64(209),
#  'pm': np.int64(1606),
#  'urgent tri': np.int64(2272),
#  'contact today': np.int64(422),
#  'today draw': np.int64(2150),
#  'draw show': np.int64(570),
#  'show prize': np.int64(1879),
#  'po box': np.int64(1610),
#  'happi': np.int64(916),
#  'birthday': np.int64(174),
#  'rakhesh': np.int64(1681),
#  'happi birthday': np.int64(917),
#  'lot love': np.int64(1204),
#  'hai': np.int64(906),
#  'new': np.int64(1408),
#  'present': np.int64(1639),
#  'gone': np.int64(838),
#  'info': np.int64(1026),
#  'come tomorrow': np.int64(394),
#  'site': np.int64(1904),
#  'download': np.int64(567),
#  'song': np.int64(1943),
#  'green': np.int64(870),
#  'quot': np.int64(1677),
#  'irrit': np.int64(1043),
#  'fail': np.int64(671),
#  'nyt': np.int64(1461),
#  'gud nyt': np.int64(896),
#  'hit': np.int64(954),
#  'move': np.int64(1360),
#  'oredi': np.int64(1513),
#  'hey': np.int64(940),
#  'sweet': np.int64(2047),
#  'moment': np.int64(1343),
#  'might': np.int64(1297),
#  'file': np.int64(699),
#  'someon': np.int64(1935),
#  'yahoo': np.int64(2464),
#  'connect': np.int64(413),
#  'suck': np.int64(2021),
#  'page': np.int64(1530),
#  'stuff': np.int64(2012),
#  'directli': np.int64(542),
#  'internet': np.int64(1032),
#  'help': np.int64(938),
#  'teas': np.int64(2068),
#  'kiss': np.int64(1096),
#  'teas kiss': np.int64(2069),
#  'eat': np.int64(594),
#  'lose': np.int64(1201),
#  'pound': np.int64(1626),
#  'bahama': np.int64(138),
#  'live': np.int64(1176),
#  'oper': np.int64(1497),
#  'either': np.int64(600),
#  'opt': np.int64(1502),
#  'speak live': np.int64(1959),
#  'live oper': np.int64(1177),
#  'oper claim': np.int64(1498),
#  'opt txt': np.int64(1503),
#  'school': np.int64(1805),
#  'alreadi': np.int64(56),
#  'close': np.int64(362),
#  'drive': np.int64(576),
#  'inch': np.int64(1022),
#  'snow': np.int64(1927),
#  'arm': np.int64(92),
#  'weak': np.int64(2353),
#  'cuz': np.int64(474),
#  'key': np.int64(1086),
#  'ok ok': np.int64(1478),
#  'today plan': np.int64(2154),
#  'late': np.int64(1120),
#  'car': np.int64(293),
#  'make sure': np.int64(1245),
#  'bold': np.int64(197),
#  'torch': np.int64(2173),
#  'theori': np.int64(2101),
#  'test': np.int64(2079),
#  'book': np.int64(201),
#  'coz': np.int64(443),
#  'wanna': np.int64(2326),
#  'print': np.int64(1647),
#  'ju': np.int64(1069),
#  'blow': np.int64(191),
#  'ju finish': np.int64(1070),
#  'pleas': np.int64(1597),
#  'pleas call': np.int64(1598),
#  'crave': np.int64(447),
#  'winner': np.int64(2401),
#  'valu': np.int64(2286),
#  'custom': np.int64(469),
#  'select': np.int64(1830),
#  'receiv': np.int64(1710),
#  'reward': np.int64(1755),
#  'collect': np.int64(378),
#  'select receiv': np.int64(1831),
#  'collect call': np.int64(379),
#  'drop': np.int64(577),
#  'travel': np.int64(2184),
#  'voucher': np.int64(2307),
#  'ntt': np.int64(1450),
#  'cr': np.int64(445),
#  'cost': np.int64(434),
#  'cost ppm': np.int64(435),
#  'convey': np.int64(425),
#  'wish': np.int64(2403),
#  'nimya': np.int64(1424),
#  'pl convey': np.int64(1584),
#  'convey birthday': np.int64(426),
#  'birthday wish': np.int64(175),
#  'wish nimya': np.int64(2406),
#  'nimya pl': np.int64(1425),
#  'today birthday': np.int64(2149),
#  'guess': np.int64(897),
#  'pub': np.int64(1663),
#  'whatev': np.int64(2381),
#  'wrong': np.int64(2441),
#  'armand': np.int64(93),
#  'final': np.int64(702),
#  'happen': np.int64(914),
#  'aftr': np.int64(36),
#  'cheaper': np.int64(331),
#  'drink': np.int64(575),
#  'sat': np.int64(1791),
#  'made': np.int64(1237),
#  'luv': np.int64(1234),
#  'kick': np.int64(1087),
#  'season': np.int64(1812),
#  'goal': np.int64(831),
#  'news': np.int64(1415),
#  'club': np.int64(364),
#  'eg': np.int64(597),
#  'wk free': np.int64(2414),
#  'ur mobil': np.int64(2262),
#  'bring': np.int64(222),
#  'cd': np.int64(314),
#  'pain': np.int64(1532),
#  'oh god': np.int64(1470),
#  'activ': np.int64(19),
#  'condit': np.int64(405),
#  'visit': np.int64(2301),
#  'www': np.int64(2446),
#  'free messag': np.int64(740),
#  'free text': np.int64(747),
#  'text messag': np.int64(2086),
#  'term condit': np.int64(2078),
#  'subscrib': np.int64(2018),
#  'gbp': np.int64(781),
#  'inc': np.int64(1021),
#  'tv': np.int64(2208),
#  'call claim': np.int64(250),
#  'studi': np.int64(2011),
#  'ring': np.int64(1759),
#  'whole': np.int64(2386),
#  'scream': np.int64(1807),
#  'pull': np.int64(1664),
#  'februari': np.int64(688),
#  'april': np.int64(86),
#  'place': np.int64(1589),
#  'stay': np.int64(1983),
#  'sinc': np.int64(1895),
#  'sister': np.int64(1902),
#  'away': np.int64(128),
#  'next': np.int64(1416),
#  'week': np.int64(2360),
#  'weekend': np.int64(2366),
#  'next week': np.int64(1417),
#  'deliveri': np.int64(518),
#  'wed': np.int64(2357),
#  'offer new': np.int64(1465),
#  'new video': np.int64(1413),
#  'call repli': np.int64(264),
#  'tot': np.int64(2174),
#  'found': np.int64(733),
#  'group': np.int64(874),
#  'liao': np.int64(1154),
#  'hostel': np.int64(981),
#  'sleep': np.int64(1911),
#  'plz': np.int64(1604),
#  'go sleep': np.int64(828),
#  'plz call': np.int64(1605),
#  'sens': np.int64(1846),
#  'email': np.int64(603),
#  'camera': np.int64(279),
#  'digit': np.int64(536),
#  'holiday': np.int64(966),
#  'safe': np.int64(1785),
#  'hav': np.int64(923),
#  'journey': np.int64(1065),
#  'coupl': np.int64(440),
#  'happi new': np.int64(919),
#  'new year': np.int64(1414),
#  'romant': np.int64(1768),
#  'flight': np.int64(718),
#  'ts': np.int64(2200),
#  'cs': np.int64(455),
#  'appli': np.int64(84),
#  'ts cs': np.int64(2201),
#  'cs appli': np.int64(456),
#  'enjoy': np.int64(616),
#  'semest': np.int64(1834),
#  'care': np.int64(295),
#  'take care': np.int64(2055),
#  'prob': np.int64(1656),
#  'problem': np.int64(1658),
#  'listen': np.int64(1174),
#  'voic': np.int64(2304),
#  'rock': np.int64(1766),
#  'anyway': np.int64(80),
#  'soon': np.int64(1948),
#  'anyway go': np.int64(81),
#  'good night': np.int64(848),
#  'speak soon': np.int64(1960),
#  'mon': np.int64(1344),
#  'haha': np.int64(905),
#  'cheap': np.int64(330),
#  'food': np.int64(724),
#  'la': np.int64(1104),
#  'ex': np.int64(653),
#  'oso': np.int64(1518),
#  'depend': np.int64(524),
#  'whether': np.int64(2385),
#  'wana': np.int64(2325),
#  'chines': np.int64(341),
#  'den': np.int64(522),
#  'prefer': np.int64(1637),
#  'deep': np.int64(509),
#  'content': np.int64(423),
#  'sigh': np.int64(1886),
#  'bare': np.int64(144),
#  'love much': np.int64(1216),
#  'tough': np.int64(2177),
#  'question': np.int64(1673),
#  'realli': np.int64(1704),
#  'around': np.int64(94),
#  'heard': np.int64(927),
#  'want come': np.int64(2328),
#  'pretti': np.int64(1642),
#  'reason': np.int64(1708),
#  'budget': np.int64(233),
#  'meant': np.int64(1275),
#  'bore': np.int64(202),
#  'cant wait': np.int64(291),
#  'see get': np.int64(1820),
#  'ignor': np.int64(1010),
#  'littl': np.int64(1175),
#  'closer': np.int64(363),
#  'bu stop': np.int64(231),
#  'cha': np.int64(319),
#  'babe': np.int64(130),
#  'hunni': np.int64(999),
#  'xxx': np.int64(2460),
#  'love jen': np.int64(1211),
#  'abl': np.int64(1),
#  'somebodi': np.int64(1934),
#  'fanci': np.int64(674),
#  'landlin': np.int64(1111),
#  'give us': np.int64(806),
#  'call landlin': np.int64(257),
#  'oop': np.int64(1495),
#  'bit': np.int64(177),
#  'tkt': np.int64(2138),
#  'euro': np.int64(639),
#  'pobox': np.int64(1611),
#  'cup final': np.int64(464),
#  'yeah get': np.int64(2476),
#  'urself': np.int64(2274),
#  'tmr': np.int64(2142),
#  'dude': np.int64(579),
#  'took': np.int64(2171),
#  'pic': np.int64(1571),
#  'sorri': np.int64(1949),
#  'fault': np.int64(685),
#  'im sorri': np.int64(1014),
#  'last nite': np.int64(1118),
#  'lunch': np.int64(1233),
#  'shall': np.int64(1865),
#  'uni': np.int64(2237),
#  'jazz': np.int64(1056),
#  'power': np.int64(1628),
#  'yoga': np.int64(2494),
#  'kb': np.int64(1076),
#  'yogasana': np.int64(2495),
#  'hey go': np.int64(942),
#  'howz': np.int64(989),
#  'stori': np.int64(2003),
#  'person stori': np.int64(1561),
#  'top': np.int64(2172),
#  'thk': np.int64(2109),
#  'confirm': np.int64(407),
#  'juz': np.int64(1071),
#  'oni': np.int64(1491),
#  'teach': np.int64(2064),
#  'ship': np.int64(1869),
#  'bloo': np.int64(186),
#  'first': np.int64(711),
#  'bowl': np.int64(208),
#  'holder': np.int64(964),
#  'pc': np.int64(1547),
#  'http': np.int64(993),
#  'dear voucher': np.int64(504),
#  'voucher holder': np.int64(2309),
#  'holder claim': np.int64(965),
#  'claim week': np.int64(356),
#  'week offer': np.int64(2363),
#  'offer pc': np.int64(1466),
#  'go http': np.int64(821),
#  'http www': np.int64(994),
#  'sound': np.int64(1953),
#  'al': np.int64(49),
#  'sound like': np.int64(1954),
#  'walk': np.int64(2318),
#  'bcoz': np.int64(150),
#  'flirt': np.int64(719),
#  'bloke': np.int64(185),
#  'join': np.int64(1061),
#  'roommat': np.int64(1770),
#  'request': np.int64(1743),
#  'mell': np.int64(1282),
#  'oru': np.int64(1516),
#  'callertun': np.int64(272),
#  'caller': np.int64(269),
#  'copi': np.int64(431),
#  'per request': np.int64(1555),
#  'oru minnaminungint': np.int64(1517),
#  'set callertun': np.int64(1858),
#  'callertun caller': np.int64(273),
#  'caller press': np.int64(270),
#  'press copi': np.int64(1641),
#  'copi friend': np.int64(432),
#  'friend callertun': np.int64(756),
#  'none': np.int64(1439),
#  'indian': np.int64(1025),
#  'version': np.int64(2288),
#  'kerala': np.int64(1083),
#  'version one': np.int64(2289),
#  'daddi': np.int64(479),
#  'arrang': np.int64(95),
#  'fetch': np.int64(694),
#  'mah': np.int64(1239),
#  'king': np.int64(1095),
#  'play': np.int64(1592),
#  'st': np.int64(1975),
#  'super': np.int64(2035),
#  'return': np.int64(1750),
#  'order': np.int64(1511),
#  'omw': np.int64(1487),
#  'ni': np.int64(1418),
#  'swt': np.int64(2050),
#  'dream': np.int64(572),
#  'gud ni': np.int64(895),
#  'well take': np.int64(2374),
#  'swt dream': np.int64(2051),
#  'month': np.int64(1347),
#  'side': np.int64(1885),
#  'sm': np.int64(1916),
#  'de': np.int64(499),
#  'bank': np.int64(142),
#  'match': np.int64(1260),
#  'app': np.int64(83),
#  'today voda': np.int64(2157),
#  'number end': np.int64(1455),
#  'end select': np.int64(610),
#  'receiv award': np.int64(1711),
#  'match pleas': np.int64(1261),
#  'claim code': np.int64(350),
#  'mother': np.int64(1357),
#  'pass': np.int64(1541),
#  'pray': np.int64(1635),
#  'forum': np.int64(730),
#  'valentin': np.int64(2282),
#  'quiz': np.int64(1676),
#  'partner': np.int64(1540),
#  'rcvd': np.int64(1691),
#  'custcar': np.int64(467),
#  'valentin day': np.int64(2283),
#  'send go': np.int64(1840),
#  'go msg': np.int64(824),
#  'msg rcvd': np.int64(1369),
#  'cours': np.int64(441),
#  'nah': np.int64(1386),
#  'straight': np.int64(2006),
#  'il': np.int64(1011),
#  'cum': np.int64(462),
#  'ga': np.int64(772),
#  'natur': np.int64(1393),
#  'trust': np.int64(2197),
#  'mani': np.int64(1253),
#  'seem': np.int64(1827),
#  'sight': np.int64(1887),
#  'remain': np.int64(1726),
#  'life': np.int64(1157),
#  'ja': np.int64(1049),
#  'everyon': np.int64(650),
#  'miss alreadi': np.int64(1314),
#  'flower': np.int64(720),
#  'touch': np.int64(2176),
#  'gift': np.int64(799),
#  'buck': np.int64(232),
#  'love ya': np.int64(1218),
#  'sign': np.int64(1888),
#  'better': np.int64(167),
#  'vijay': np.int64(2297),
#  'dey': np.int64(527),
#  'congrat': np.int64(408),
#  'id': np.int64(1006),
#  'go home': np.int64(820),
#  'import': np.int64(1018),
#  'servic': np.int64(1853),
#  'announc': np.int64(69),
#  'freephon': np.int64(750),
#  'custom servic': np.int64(471),
#  'servic announc': np.int64(1854),
#  'call freephon': np.int64(254),
#  'gener': np.int64(786),
#  'dictionari': np.int64(529),
#  'piec': np.int64(1576),
#  'research': np.int64(1744),
#  'darlin': np.int64(485),
#  'film': np.int64(701),
#  'mate': np.int64(1262),
#  'xx': np.int64(2459),
#  'wednesday': np.int64(2358),
#  'truth': np.int64(2198),
#  'graviti': np.int64(863),
#  'read': np.int64(1696),
#  'light': np.int64(1159),
#  'heavi': np.int64(932),
#  'beauti truth': np.int64(154),
#  'truth graviti': np.int64(2199),
#  'graviti read': np.int64(864),
#  'read care': np.int64(1697),
#  'care heart': np.int64(296),
#  'heart feel': np.int64(930),
#  'feel light': np.int64(691),
#  'light someon': np.int64(1160),
#  'someon feel': np.int64(1936),
#  'feel heavi': np.int64(690),
#  'heavi someon': np.int64(933),
#  'someon leav': np.int64(1938),
#  'detail': np.int64(526),
#  'fri': np.int64(753),
#  'wont': np.int64(2423),
#  'doctor': np.int64(552),
#  'hesit': np.int64(939),
#  'second': np.int64(1814),
#  'chang': np.int64(324),
#  'noth': np.int64(1446),
#  'tone': np.int64(2162),
#  'weekli': np.int64(2367),
#  'credit': np.int64(450),
#  'gonna': np.int64(839),
#  'later tonight': np.int64(1123),
#  'ok come': np.int64(1474),
#  'come home': np.int64(391),
#  'nokia': np.int64(1429),
#  'mob': np.int64(1326),
#  'txting': np.int64(2224),
#  'wq': np.int64(2437),
#  'norm': np.int64(1442),
#  'free st': np.int64(746),
#  'st week': np.int64(1976),
#  'week nokia': np.int64(2362),
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

model.fit(x_train_b,y_train)
# Out:
# MultinomialNB()

# %%
y_pred =model.predict(x_test_b)

# %%
from sklearn.metrics import accuracy_score,classification_report

print(accuracy_score(y_pred,y_test))
print(classification_report(y_pred,y_test))
# Out:
# 0.9829596412556054
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       168
#            1       1.00      0.98      0.99       947
#
#     accuracy                           0.98      1115
#    macro avg       0.96      0.98      0.97      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# # create TF-IDF model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(max_features=2500,ngram_range=(1,2)
                     )

# %%
x_train_t = tv.fit_transform(x_train).toarray()
x_test_t = tv.transform(x_test).toarray()

# %%
tv.vocabulary_
# Out:
# {'hungri': np.int64(998),
#  'gay': np.int64(778),
#  'guy': np.int64(900),
#  'feel': np.int64(689),
#  'call': np.int64(247),
#  'min': np.int64(1299),
#  'stop': np.int64(1993),
#  'text': np.int64(2080),
#  'call min': np.int64(259),
#  'min stop': np.int64(1302),
#  'stop text': np.int64(1999),
#  'text call': np.int64(2082),
#  'pick': np.int64(1572),
#  'anoth': np.int64(70),
#  'th': np.int64(2091),
#  'done': np.int64(557),
#  'ok': np.int64(1473),
#  'thanx': np.int64(2097),
#  'gd': np.int64(783),
#  'nite': np.int64(1426),
#  'ok thanx': np.int64(1482),
#  'still': np.int64(1986),
#  'get': np.int64(789),
#  'good': np.int64(841),
#  'loverboy': np.int64(1220),
#  'keep': np.int64(1077),
#  'come': np.int64(388),
#  'queen': np.int64(1672),
#  'hmmm': np.int64(960),
#  'ach': np.int64(15),
#  'speak': np.int64(1958),
#  'miss': np.int64(1313),
#  'cool': np.int64(429),
#  'see': np.int64(1819),
#  'ya': np.int64(2463),
#  'see ya': np.int64(1826),
#  'went': np.int64(2377),
#  'attend': np.int64(113),
#  'two': np.int64(2211),
#  'round': np.int64(1772),
#  'today': np.int64(2147),
#  'reach': np.int64(1693),
#  'home': np.int64(970),
#  'reach home': np.int64(1695),
#  'movi': np.int64(1361),
#  'theatr': np.int64(2100),
#  'go': np.int64(812),
#  'watch': np.int64(2342),
#  'unlimit': np.int64(2239),
#  'pay': np.int64(1545),
#  'go watch': np.int64(830),
#  'best': np.int64(164),
#  'line': np.int64(1167),
#  'said': np.int64(1786),
#  'love': np.int64(1208),
#  'wait': np.int64(2313),
#  'till': np.int64(2126),
#  'day': np.int64(491),
#  'forget': np.int64(727),
#  'realiz': np.int64(1703),
#  'cannot': np.int64(286),
#  'gn': np.int64(810),
#  'wait till': np.int64(2316),
#  'aight': np.int64(43),
#  'lemm': np.int64(1147),
#  'know': np.int64(1099),
#  'lemm know': np.int64(1148),
#  'met': np.int64(1294),
#  'choos': np.int64(343),
#  'friend': np.int64(755),
#  'long': np.int64(1191),
#  'world': np.int64(2429),
#  'stand': np.int64(1978),
#  'friendship': np.int64(760),
#  'never': np.int64(1407),
#  'end': np.int64(608),
#  'let': np.int64(1151),
#  'forev': np.int64(726),
#  'gud': np.int64(892),
#  'thinkin': np.int64(2108),
#  'malaria': np.int64(1247),
#  'relax': np.int64(1723),
#  'children': np.int64(340),
#  'cant': np.int64(287),
#  'would': np.int64(2435),
#  'wors': np.int64(2431),
#  'take': np.int64(2054),
#  'enough': np.int64(618),
#  'replac': np.int64(1735),
#  'give': np.int64(804),
#  'med': np.int64(1276),
#  'vomit': np.int64(2305),
#  'self': np.int64(1832),
#  'limit': np.int64(1166),
#  'ill': np.int64(1012),
#  'mean': np.int64(1274),
#  'complet': np.int64(401),
#  'like': np.int64(1161),
#  'bad': np.int64(135),
#  'dat': np.int64(488),
#  'gal': np.int64(773),
#  'wat': np.int64(2338),
#  'hand': np.int64(911),
#  'phone': np.int64(1565),
#  'chat': np.int64(329),
#  'wit': np.int64(2408),
#  'told': np.int64(2159),
#  'earlier': np.int64(589),
#  'princess': np.int64(1646),
#  'number': np.int64(1453),
#  'ur': np.int64(2248),
#  'award': np.int64(122),
#  'citi': np.int64(347),
#  'break': np.int64(219),
#  'could': np.int64(438),
#  'win': np.int64(2396),
#  'summer': np.int64(2027),
#  'shop': np.int64(1873),
#  'spree': np.int64(1973),
#  'everi': np.int64(644),
#  'wk': np.int64(2413),
#  'txt': np.int64(2213),
#  'store': np.int64(2002),
#  'tsc': np.int64(2202),
#  'age': np.int64(37),
#  'ur award': np.int64(2249),
#  'shop spree': np.int64(1874),
#  'everi wk': np.int64(648),
#  'wk txt': np.int64(2415),
#  'wonder': np.int64(2422),
#  'okay': np.int64(1483),
#  'uncl': np.int64(2235),
#  'john': np.int64(1059),
#  'thing': np.int64(2102),
#  'nigeria': np.int64(1421),
#  'lt': np.int64(1223),
#  'gt': np.int64(876),
#  'dollar': np.int64(556),
#  'year': np.int64(2481),
#  'sent': np.int64(1847),
#  'plan': np.int64(1590),
#  'back': np.int64(133),
#  'expect': np.int64(661),
#  'anyth': np.int64(76),
#  'practic': np.int64(1634),
#  'someth': np.int64(1939),
#  'let know': np.int64(1152),
#  'lt gt': np.int64(1225),
#  'gt dollar': np.int64(878),
#  'pay back': np.int64(1546),
#  'say': np.int64(1799),
#  'slowli': np.int64(1915),
#  'god': np.int64(832),
#  'amp': np.int64(63),
#  'need': np.int64(1399),
#  'clean': np.int64(358),
#  'heart': np.int64(928),
#  'blood': np.int64(187),
#  'send': np.int64(1836),
#  'ten': np.int64(2074),
#  'special': np.int64(1961),
#  'peopl': np.int64(1549),
#  'miracl': np.int64(1312),
#  'tomorrow': np.int64(2161),
#  'pl': np.int64(1582),
#  'god love': np.int64(833),
#  'heart blood': np.int64(929),
#  'blood send': np.int64(188),
#  'pl pl': np.int64(1586),
#  'tonight': np.int64(2169),
#  'free': np.int64(735),
#  'sir': np.int64(1900),
#  'free call': np.int64(736),
#  'call sir': np.int64(266),
#  'class': np.int64(357),
#  'holla': np.int64(969),
#  'later': np.int64(1121),
#  'run': np.int64(1779),
#  'cross': np.int64(452),
#  'street': np.int64(2007),
#  'urgent': np.int64(2269),
#  'mobil': np.int64(1328),
#  'prize': np.int64(1650),
#  'guarante': np.int64(888),
#  'land': np.int64(1108),
#  'claim': np.int64(348),
#  'valid': np.int64(2284),
#  'hr': np.int64(991),
#  'ppm': np.int64(1630),
#  'urgent mobil': np.int64(2270),
#  'mobil number': np.int64(1335),
#  'number award': np.int64(1454),
#  'award prize': np.int64(126),
#  'prize guarante': np.int64(1653),
#  'guarante call': np.int64(889),
#  'call land': np.int64(256),
#  'land line': np.int64(1109),
#  'line claim': np.int64(1168),
#  'claim valid': np.int64(355),
#  'valid hr': np.int64(2285),
#  'hr ppm': np.int64(992),
#  'way': np.int64(2346),
#  'cup': np.int64(463),
#  'work': np.int64(2426),
#  'bu': np.int64(230),
#  'text way': np.int64(2089),
#  'half': np.int64(908),
#  'hour': np.int64(984),
#  'half hour': np.int64(909),
#  'im': np.int64(1013),
#  'librari': np.int64(1155),
#  'direct': np.int64(541),
#  'access': np.int64(8),
#  'per': np.int64(1550),
#  'msg': np.int64(1367),
#  'get free': np.int64(791),
#  'per day': np.int64(1551),
#  'txt stop': np.int64(2221),
#  'hang': np.int64(913),
#  'brother': np.int64(225),
#  'famili': np.int64(673),
#  'tri': np.int64(2187),
#  'contact': np.int64(416),
#  'repli': np.int64(1736),
#  'offer': np.int64(1463),
#  'video': np.int64(2291),
#  'anytim': np.int64(78),
#  'network': np.int64(1403),
#  'price': np.int64(1643),
#  'rental': np.int64(1732),
#  'camcord': np.int64(274),
#  'tri contact': np.int64(2189),
#  'video phone': np.int64(2292),
#  'phone anytim': np.int64(1566),
#  'anytim network': np.int64(79),
#  'network min': np.int64(1404),
#  'min half': np.int64(1300),
#  'half price': np.int64(910),
#  'price line': np.int64(1644),
#  'line rental': np.int64(1169),
#  'camcord repli': np.int64(275),
#  'repli call': np.int64(1737),
#  'yup': np.int64(2499),
#  'lor': np.int64(1198),
#  'dun': np.int64(581),
#  'wan': np.int64(2320),
#  'anyth lor': np.int64(77),
#  'lor dun': np.int64(1199),
#  'dun wan': np.int64(584),
#  'what': np.int64(2380),
#  'hill': np.int64(953),
#  'hope': np.int64(974),
#  'great': np.int64(865),
#  'fine': np.int64(708),
#  'busi': np.int64(237),
#  'though': np.int64(2112),
#  'hope great': np.int64(977),
#  'great day': np.int64(866),
#  'danc': np.int64(482),
#  'one': np.int64(1488),
#  'time': np.int64(2127),
#  'minut': np.int64(1307),
#  'ur home': np.int64(2257),
#  'gt minut': np.int64(884),
#  'fix': np.int64(714),
#  'spell': np.int64(1965),
#  'sometim': np.int64(1941),
#  'word': np.int64(2424),
#  'figur': np.int64(698),
#  'din': np.int64(538),
#  'wan come': np.int64(2321),
#  'think': np.int64(2103),
#  'cash': np.int64(301),
#  'def': np.int64(511),
#  'readi': np.int64(1699),
#  'still need': np.int64(1989),
#  'need get': np.int64(1400),
#  'buy': np.int64(238),
#  'space': np.int64(1957),
#  'chanc': np.int64(321),
#  'arcad': np.int64(88),
#  'game': np.int64(774),
#  'press': np.int64(1640),
#  'std': np.int64(1984),
#  'wap': np.int64(2335),
#  'charg': np.int64(327),
#  'co': np.int64(366),
#  'uk': np.int64(2229),
#  'term': np.int64(2077),
#  'set': np.int64(1857),
#  'chanc win': np.int64(323),
#  'co uk': np.int64(369),
#  'want': np.int64(2327),
#  'us': np.int64(2275),
#  'awesom': np.int64(129),
#  'deal': np.int64(501),
#  'last': np.int64(1116),
#  'night': np.int64(1422),
#  'yeah': np.int64(2475),
#  'last night': np.int64(1117),
#  'talk': np.int64(2058),
#  'bout': np.int64(207),
#  'earli': np.int64(588),
#  'morn': np.int64(1352),
#  'almost': np.int64(54),
#  'noon': np.int64(1440),
#  'trip': np.int64(2192),
#  'big': np.int64(169),
#  'especi': np.int64(634),
#  'pl give': np.int64(1585),
#  'privat': np.int64(1648),
#  'account': np.int64(11),
#  'statement': np.int64(1981),
#  'show': np.int64(1877),
#  'bonu': np.int64(198),
#  'point': np.int64(1614),
#  'identifi': np.int64(1008),
#  'code': np.int64(370),
#  'expir': np.int64(664),
#  'privat account': np.int64(1649),
#  'account statement': np.int64(14),
#  'statement show': np.int64(1982),
#  'claim call': np.int64(349),
#  'call identifi': np.int64(255),
#  'identifi code': np.int64(1009),
#  'code expir': np.int64(371),
#  'huh': np.int64(996),
#  'hous': np.int64(985),
#  'empti': np.int64(606),
#  'right': np.int64(1757),
#  'dont': np.int64(558),
#  'ask': np.int64(100),
#  'dont know': np.int64(559),
#  'tell': np.int64(2071),
#  'bb': np.int64(148),
#  'longer': np.int64(1193),
#  'comin': np.int64(396),
#  'money': np.int64(1346),
#  'aint': np.int64(44),
#  'messag': np.int64(1290),
#  'name': np.int64(1388),
#  'date': np.int64(489),
#  'lot': np.int64(1203),
#  'that': np.int64(2098),
#  'everyth': np.int64(651),
#  'via': np.int64(2290),
#  'fullonsm': np.int64(766),
#  'com': np.int64(385),
#  'miss sent': np.int64(1318),
#  'sent via': np.int64(1849),
#  'fullonsm com': np.int64(767),
#  'alright': np.int64(57),
#  'hook': np.int64(973),
#  'hear': np.int64(926),
#  'settl': np.int64(1859),
#  'well': np.int64(2372),
#  'da': np.int64(475),
#  'fren': np.int64(752),
#  'meet': np.int64(1277),
#  'also': np.int64(59),
#  'yesterday': np.int64(2487),
#  'til': np.int64(2125),
#  'dear': np.int64(502),
#  'saw': np.int64(1798),
#  'captain': np.int64(292),
#  'parti': np.int64(1539),
#  'grand': np.int64(862),
#  'project': np.int64(1660),
#  'centr': np.int64(318),
#  'boy': np.int64(214),
#  'oh': np.int64(1469),
#  'guid': np.int64(899),
#  'plu': np.int64(1603),
#  'legal': np.int64(1144),
#  'system': np.int64(2052),
#  'slow': np.int64(1914),
#  'gr': np.int64(860),
#  'start': np.int64(1980),
#  'onlin': np.int64(1492),
#  'honey': np.int64(972),
#  'moon': np.int64(1350),
#  'gr day': np.int64(861),
#  'wot': np.int64(2434),
#  'wear': np.int64(2354),
#  'shirt': np.int64(1870),
#  'alway': np.int64(60),
#  'put': np.int64(1669),
#  'pictur': np.int64(1574),
#  'ass': np.int64(107),
#  'facebook': np.int64(669),
#  'open': np.int64(1496),
#  'ever': np.int64(643),
#  'room': np.int64(1769),
#  'hurt': np.int64(1001),
#  'make': np.int64(1242),
#  'make feel': np.int64(1244),
#  'friday': np.int64(754),
#  'leav': np.int64(1140),
#  'except': np.int64(657),
#  'usf': np.int64(2278),
#  'time tonight': np.int64(2133),
#  'shoot': np.int64(1872),
#  'load': np.int64(1179),
#  'get readi': np.int64(793),
#  'girl': np.int64(802),
#  'se': np.int64(1809),
#  'bloodi': np.int64(189),
#  'shit': np.int64(1871),
#  'fuck': np.int64(764),
#  'face': np.int64(668),
#  'rememb': np.int64(1727),
#  'must': np.int64(1383),
#  'decid': np.int64(506),
#  'get back': np.int64(790),
#  'use': np.int64(2276),
#  'hello': np.int64(937),
#  'find': np.int64(704),
#  'job': np.int64(1058),
#  'lazi': np.int64(1132),
#  'toward': np.int64(2179),
#  'net': np.int64(1402),
#  'mummi': np.int64(1376),
#  'boytoy': np.int64(215),
#  'thank': np.int64(2092),
#  'tomo': np.int64(2160),
#  'pussi': np.int64(1668),
#  'perfect': np.int64(1558),
#  'congratul': np.int64(410),
#  'xma': np.int64(2457),
#  'easi': np.int64(591),
#  'bt': np.int64(227),
#  'nation': np.int64(1391),
#  'rate': np.int64(1685),
#  'congratul thank': np.int64(411),
#  'thank good': np.int64(2094),
#  'good friend': np.int64(845),
#  'xma prize': np.int64(2458),
#  'prize claim': np.int64(1652),
#  'claim easi': np.int64(351),
#  'easi call': np.int64(592),
#  'call per': np.int64(263),
#  'per minut': np.int64(1553),
#  'minut bt': np.int64(1308),
#  'bt nation': np.int64(228),
#  'nation rate': np.int64(1392),
#  'wen': np.int64(2375),
#  'lift': np.int64(1158),
#  'knw': np.int64(1101),
#  'wt': np.int64(2442),
#  'real': np.int64(1700),
#  'ye': np.int64(2470),
#  'girlfrnd': np.int64(803),
#  'moral': np.int64(1351),
#  'person': np.int64(1559),
#  'tht': np.int64(2116),
#  'fli': np.int64(717),
#  'lol': np.int64(1187),
#  'yo': np.int64(2492),
#  'beauti': np.int64(153),
#  'ive': np.int64(1047),
#  'seen': np.int64(1829),
#  'babi': np.int64(132),
#  'common': np.int64(397),
#  'address': np.int64(23),
#  'quit': np.int64(1675),
#  'sure': np.int64(2039),
#  'thought': np.int64(2113),
#  'think could': np.int64(2104),
#  'nice': np.int64(1419),
#  'mm': np.int64(1322),
#  'fun': np.int64(768),
#  'promis': np.int64(1661),
#  'even': np.int64(641),
#  'dinner': np.int64(539),
#  'yet': np.int64(2488),
#  'actual': np.int64(20),
#  'nvm': np.int64(1457),
#  'got': np.int64(854),
#  'ish': np.int64(1044),
#  'gt ish': np.int64(880),
#  'oki': np.int64(1484),
#  'want go': np.int64(2329),
#  'lar': np.int64(1115),
#  'si': np.int64(1883),
#  'art': np.int64(98),
#  'co si': np.int64(368),
#  'may': np.int64(1271),
#  'call later': np.int64(258),
#  'worri': np.int64(2430),
#  'hair': np.int64(907),
#  'suppos': np.int64(2037),
#  'town': np.int64(2180),
#  'mind': np.int64(1304),
#  'bedroom': np.int64(157),
#  'sed': np.int64(1817),
#  'sexi': np.int64(1861),
#  'mood': np.int64(1348),
#  'came': np.int64(276),
#  'latr': np.int64(1128),
#  'wid': np.int64(2387),
#  'cake': np.int64(244),
#  'wife': np.int64(2392),
#  'said mind': np.int64(1787),
#  'mind go': np.int64(1305),
#  'go bedroom': np.int64(815),
#  'bedroom minut': np.int64(158),
#  'minut ok': np.int64(1311),
#  'ok sed': np.int64(1480),
#  'sed sexi': np.int64(1818),
#  'sexi mood': np.int64(1863),
#  'mood came': np.int64(1349),
#  'came minut': np.int64(278),
#  'minut latr': np.int64(1309),
#  'latr wid': np.int64(1129),
#  'wid cake': np.int64(2388),
#  'cake wife': np.int64(245),
#  'finish': np.int64(710),
#  'lect': np.int64(1141),
#  'wat time': np.int64(2340),
#  'time finish': np.int64(2129),
#  'much': np.int64(1374),
#  'mu': np.int64(1373),
#  'sort': np.int64(1952),
#  'situat': np.int64(1905),
#  'ah': np.int64(39),
#  'dunno': np.int64(585),
#  'learn': np.int64(1138),
#  'pilat': np.int64(1577),
#  'tuition': np.int64(2206),
#  'go one': np.int64(825),
#  'avail': np.int64(116),
#  'rd': np.int64(1692),
#  'india': np.int64(1024),
#  'record': np.int64(1714),
#  'draw': np.int64(568),
#  'po': np.int64(1609),
#  'box': np.int64(209),
#  'pm': np.int64(1606),
#  'urgent tri': np.int64(2272),
#  'contact today': np.int64(422),
#  'today draw': np.int64(2150),
#  'draw show': np.int64(570),
#  'show prize': np.int64(1879),
#  'po box': np.int64(1610),
#  'happi': np.int64(916),
#  'birthday': np.int64(174),
#  'rakhesh': np.int64(1681),
#  'happi birthday': np.int64(917),
#  'lot love': np.int64(1204),
#  'hai': np.int64(906),
#  'new': np.int64(1408),
#  'present': np.int64(1639),
#  'gone': np.int64(838),
#  'info': np.int64(1026),
#  'come tomorrow': np.int64(394),
#  'site': np.int64(1904),
#  'download': np.int64(567),
#  'song': np.int64(1943),
#  'green': np.int64(870),
#  'quot': np.int64(1677),
#  'irrit': np.int64(1043),
#  'fail': np.int64(671),
#  'nyt': np.int64(1461),
#  'gud nyt': np.int64(896),
#  'hit': np.int64(954),
#  'move': np.int64(1360),
#  'oredi': np.int64(1513),
#  'hey': np.int64(940),
#  'sweet': np.int64(2047),
#  'moment': np.int64(1343),
#  'might': np.int64(1297),
#  'file': np.int64(699),
#  'someon': np.int64(1935),
#  'yahoo': np.int64(2464),
#  'connect': np.int64(413),
#  'suck': np.int64(2021),
#  'page': np.int64(1530),
#  'stuff': np.int64(2012),
#  'directli': np.int64(542),
#  'internet': np.int64(1032),
#  'help': np.int64(938),
#  'teas': np.int64(2068),
#  'kiss': np.int64(1096),
#  'teas kiss': np.int64(2069),
#  'eat': np.int64(594),
#  'lose': np.int64(1201),
#  'pound': np.int64(1626),
#  'bahama': np.int64(138),
#  'live': np.int64(1176),
#  'oper': np.int64(1497),
#  'either': np.int64(600),
#  'opt': np.int64(1502),
#  'speak live': np.int64(1959),
#  'live oper': np.int64(1177),
#  'oper claim': np.int64(1498),
#  'opt txt': np.int64(1503),
#  'school': np.int64(1805),
#  'alreadi': np.int64(56),
#  'close': np.int64(362),
#  'drive': np.int64(576),
#  'inch': np.int64(1022),
#  'snow': np.int64(1927),
#  'arm': np.int64(92),
#  'weak': np.int64(2353),
#  'cuz': np.int64(474),
#  'key': np.int64(1086),
#  'ok ok': np.int64(1478),
#  'today plan': np.int64(2154),
#  'late': np.int64(1120),
#  'car': np.int64(293),
#  'make sure': np.int64(1245),
#  'bold': np.int64(197),
#  'torch': np.int64(2173),
#  'theori': np.int64(2101),
#  'test': np.int64(2079),
#  'book': np.int64(201),
#  'coz': np.int64(443),
#  'wanna': np.int64(2326),
#  'print': np.int64(1647),
#  'ju': np.int64(1069),
#  'blow': np.int64(191),
#  'ju finish': np.int64(1070),
#  'pleas': np.int64(1597),
#  'pleas call': np.int64(1598),
#  'crave': np.int64(447),
#  'winner': np.int64(2401),
#  'valu': np.int64(2286),
#  'custom': np.int64(469),
#  'select': np.int64(1830),
#  'receiv': np.int64(1710),
#  'reward': np.int64(1755),
#  'collect': np.int64(378),
#  'select receiv': np.int64(1831),
#  'collect call': np.int64(379),
#  'drop': np.int64(577),
#  'travel': np.int64(2184),
#  'voucher': np.int64(2307),
#  'ntt': np.int64(1450),
#  'cr': np.int64(445),
#  'cost': np.int64(434),
#  'cost ppm': np.int64(435),
#  'convey': np.int64(425),
#  'wish': np.int64(2403),
#  'nimya': np.int64(1424),
#  'pl convey': np.int64(1584),
#  'convey birthday': np.int64(426),
#  'birthday wish': np.int64(175),
#  'wish nimya': np.int64(2406),
#  'nimya pl': np.int64(1425),
#  'today birthday': np.int64(2149),
#  'guess': np.int64(897),
#  'pub': np.int64(1663),
#  'whatev': np.int64(2381),
#  'wrong': np.int64(2441),
#  'armand': np.int64(93),
#  'final': np.int64(702),
#  'happen': np.int64(914),
#  'aftr': np.int64(36),
#  'cheaper': np.int64(331),
#  'drink': np.int64(575),
#  'sat': np.int64(1791),
#  'made': np.int64(1237),
#  'luv': np.int64(1234),
#  'kick': np.int64(1087),
#  'season': np.int64(1812),
#  'goal': np.int64(831),
#  'news': np.int64(1415),
#  'club': np.int64(364),
#  'eg': np.int64(597),
#  'wk free': np.int64(2414),
#  'ur mobil': np.int64(2262),
#  'bring': np.int64(222),
#  'cd': np.int64(314),
#  'pain': np.int64(1532),
#  'oh god': np.int64(1470),
#  'activ': np.int64(19),
#  'condit': np.int64(405),
#  'visit': np.int64(2301),
#  'www': np.int64(2446),
#  'free messag': np.int64(740),
#  'free text': np.int64(747),
#  'text messag': np.int64(2086),
#  'term condit': np.int64(2078),
#  'subscrib': np.int64(2018),
#  'gbp': np.int64(781),
#  'inc': np.int64(1021),
#  'tv': np.int64(2208),
#  'call claim': np.int64(250),
#  'studi': np.int64(2011),
#  'ring': np.int64(1759),
#  'whole': np.int64(2386),
#  'scream': np.int64(1807),
#  'pull': np.int64(1664),
#  'februari': np.int64(688),
#  'april': np.int64(86),
#  'place': np.int64(1589),
#  'stay': np.int64(1983),
#  'sinc': np.int64(1895),
#  'sister': np.int64(1902),
#  'away': np.int64(128),
#  'next': np.int64(1416),
#  'week': np.int64(2360),
#  'weekend': np.int64(2366),
#  'next week': np.int64(1417),
#  'deliveri': np.int64(518),
#  'wed': np.int64(2357),
#  'offer new': np.int64(1465),
#  'new video': np.int64(1413),
#  'call repli': np.int64(264),
#  'tot': np.int64(2174),
#  'found': np.int64(733),
#  'group': np.int64(874),
#  'liao': np.int64(1154),
#  'hostel': np.int64(981),
#  'sleep': np.int64(1911),
#  'plz': np.int64(1604),
#  'go sleep': np.int64(828),
#  'plz call': np.int64(1605),
#  'sens': np.int64(1846),
#  'email': np.int64(603),
#  'camera': np.int64(279),
#  'digit': np.int64(536),
#  'holiday': np.int64(966),
#  'safe': np.int64(1785),
#  'hav': np.int64(923),
#  'journey': np.int64(1065),
#  'coupl': np.int64(440),
#  'happi new': np.int64(919),
#  'new year': np.int64(1414),
#  'romant': np.int64(1768),
#  'flight': np.int64(718),
#  'ts': np.int64(2200),
#  'cs': np.int64(455),
#  'appli': np.int64(84),
#  'ts cs': np.int64(2201),
#  'cs appli': np.int64(456),
#  'enjoy': np.int64(616),
#  'semest': np.int64(1834),
#  'care': np.int64(295),
#  'take care': np.int64(2055),
#  'prob': np.int64(1656),
#  'problem': np.int64(1658),
#  'listen': np.int64(1174),
#  'voic': np.int64(2304),
#  'rock': np.int64(1766),
#  'anyway': np.int64(80),
#  'soon': np.int64(1948),
#  'anyway go': np.int64(81),
#  'good night': np.int64(848),
#  'speak soon': np.int64(1960),
#  'mon': np.int64(1344),
#  'haha': np.int64(905),
#  'cheap': np.int64(330),
#  'food': np.int64(724),
#  'la': np.int64(1104),
#  'ex': np.int64(653),
#  'oso': np.int64(1518),
#  'depend': np.int64(524),
#  'whether': np.int64(2385),
#  'wana': np.int64(2325),
#  'chines': np.int64(341),
#  'den': np.int64(522),
#  'prefer': np.int64(1637),
#  'deep': np.int64(509),
#  'content': np.int64(423),
#  'sigh': np.int64(1886),
#  'bare': np.int64(144),
#  'love much': np.int64(1216),
#  'tough': np.int64(2177),
#  'question': np.int64(1673),
#  'realli': np.int64(1704),
#  'around': np.int64(94),
#  'heard': np.int64(927),
#  'want come': np.int64(2328),
#  'pretti': np.int64(1642),
#  'reason': np.int64(1708),
#  'budget': np.int64(233),
#  'meant': np.int64(1275),
#  'bore': np.int64(202),
#  'cant wait': np.int64(291),
#  'see get': np.int64(1820),
#  'ignor': np.int64(1010),
#  'littl': np.int64(1175),
#  'closer': np.int64(363),
#  'bu stop': np.int64(231),
#  'cha': np.int64(319),
#  'babe': np.int64(130),
#  'hunni': np.int64(999),
#  'xxx': np.int64(2460),
#  'love jen': np.int64(1211),
#  'abl': np.int64(1),
#  'somebodi': np.int64(1934),
#  'fanci': np.int64(674),
#  'landlin': np.int64(1111),
#  'give us': np.int64(806),
#  'call landlin': np.int64(257),
#  'oop': np.int64(1495),
#  'bit': np.int64(177),
#  'tkt': np.int64(2138),
#  'euro': np.int64(639),
#  'pobox': np.int64(1611),
#  'cup final': np.int64(464),
#  'yeah get': np.int64(2476),
#  'urself': np.int64(2274),
#  'tmr': np.int64(2142),
#  'dude': np.int64(579),
#  'took': np.int64(2171),
#  'pic': np.int64(1571),
#  'sorri': np.int64(1949),
#  'fault': np.int64(685),
#  'im sorri': np.int64(1014),
#  'last nite': np.int64(1118),
#  'lunch': np.int64(1233),
#  'shall': np.int64(1865),
#  'uni': np.int64(2237),
#  'jazz': np.int64(1056),
#  'power': np.int64(1628),
#  'yoga': np.int64(2494),
#  'kb': np.int64(1076),
#  'yogasana': np.int64(2495),
#  'hey go': np.int64(942),
#  'howz': np.int64(989),
#  'stori': np.int64(2003),
#  'person stori': np.int64(1561),
#  'top': np.int64(2172),
#  'thk': np.int64(2109),
#  'confirm': np.int64(407),
#  'juz': np.int64(1071),
#  'oni': np.int64(1491),
#  'teach': np.int64(2064),
#  'ship': np.int64(1869),
#  'bloo': np.int64(186),
#  'first': np.int64(711),
#  'bowl': np.int64(208),
#  'holder': np.int64(964),
#  'pc': np.int64(1547),
#  'http': np.int64(993),
#  'dear voucher': np.int64(504),
#  'voucher holder': np.int64(2309),
#  'holder claim': np.int64(965),
#  'claim week': np.int64(356),
#  'week offer': np.int64(2363),
#  'offer pc': np.int64(1466),
#  'go http': np.int64(821),
#  'http www': np.int64(994),
#  'sound': np.int64(1953),
#  'al': np.int64(49),
#  'sound like': np.int64(1954),
#  'walk': np.int64(2318),
#  'bcoz': np.int64(150),
#  'flirt': np.int64(719),
#  'bloke': np.int64(185),
#  'join': np.int64(1061),
#  'roommat': np.int64(1770),
#  'request': np.int64(1743),
#  'mell': np.int64(1282),
#  'oru': np.int64(1516),
#  'callertun': np.int64(272),
#  'caller': np.int64(269),
#  'copi': np.int64(431),
#  'per request': np.int64(1555),
#  'oru minnaminungint': np.int64(1517),
#  'set callertun': np.int64(1858),
#  'callertun caller': np.int64(273),
#  'caller press': np.int64(270),
#  'press copi': np.int64(1641),
#  'copi friend': np.int64(432),
#  'friend callertun': np.int64(756),
#  'none': np.int64(1439),
#  'indian': np.int64(1025),
#  'version': np.int64(2288),
#  'kerala': np.int64(1083),
#  'version one': np.int64(2289),
#  'daddi': np.int64(479),
#  'arrang': np.int64(95),
#  'fetch': np.int64(694),
#  'mah': np.int64(1239),
#  'king': np.int64(1095),
#  'play': np.int64(1592),
#  'st': np.int64(1975),
#  'super': np.int64(2035),
#  'return': np.int64(1750),
#  'order': np.int64(1511),
#  'omw': np.int64(1487),
#  'ni': np.int64(1418),
#  'swt': np.int64(2050),
#  'dream': np.int64(572),
#  'gud ni': np.int64(895),
#  'well take': np.int64(2374),
#  'swt dream': np.int64(2051),
#  'month': np.int64(1347),
#  'side': np.int64(1885),
#  'sm': np.int64(1916),
#  'de': np.int64(499),
#  'bank': np.int64(142),
#  'match': np.int64(1260),
#  'app': np.int64(83),
#  'today voda': np.int64(2157),
#  'number end': np.int64(1455),
#  'end select': np.int64(610),
#  'receiv award': np.int64(1711),
#  'match pleas': np.int64(1261),
#  'claim code': np.int64(350),
#  'mother': np.int64(1357),
#  'pass': np.int64(1541),
#  'pray': np.int64(1635),
#  'forum': np.int64(730),
#  'valentin': np.int64(2282),
#  'quiz': np.int64(1676),
#  'partner': np.int64(1540),
#  'rcvd': np.int64(1691),
#  'custcar': np.int64(467),
#  'valentin day': np.int64(2283),
#  'send go': np.int64(1840),
#  'go msg': np.int64(824),
#  'msg rcvd': np.int64(1369),
#  'cours': np.int64(441),
#  'nah': np.int64(1386),
#  'straight': np.int64(2006),
#  'il': np.int64(1011),
#  'cum': np.int64(462),
#  'ga': np.int64(772),
#  'natur': np.int64(1393),
#  'trust': np.int64(2197),
#  'mani': np.int64(1253),
#  'seem': np.int64(1827),
#  'sight': np.int64(1887),
#  'remain': np.int64(1726),
#  'life': np.int64(1157),
#  'ja': np.int64(1049),
#  'everyon': np.int64(650),
#  'miss alreadi': np.int64(1314),
#  'flower': np.int64(720),
#  'touch': np.int64(2176),
#  'gift': np.int64(799),
#  'buck': np.int64(232),
#  'love ya': np.int64(1218),
#  'sign': np.int64(1888),
#  'better': np.int64(167),
#  'vijay': np.int64(2297),
#  'dey': np.int64(527),
#  'congrat': np.int64(408),
#  'id': np.int64(1006),
#  'go home': np.int64(820),
#  'import': np.int64(1018),
#  'servic': np.int64(1853),
#  'announc': np.int64(69),
#  'freephon': np.int64(750),
#  'custom servic': np.int64(471),
#  'servic announc': np.int64(1854),
#  'call freephon': np.int64(254),
#  'gener': np.int64(786),
#  'dictionari': np.int64(529),
#  'piec': np.int64(1576),
#  'research': np.int64(1744),
#  'darlin': np.int64(485),
#  'film': np.int64(701),
#  'mate': np.int64(1262),
#  'xx': np.int64(2459),
#  'wednesday': np.int64(2358),
#  'truth': np.int64(2198),
#  'graviti': np.int64(863),
#  'read': np.int64(1696),
#  'light': np.int64(1159),
#  'heavi': np.int64(932),
#  'beauti truth': np.int64(154),
#  'truth graviti': np.int64(2199),
#  'graviti read': np.int64(864),
#  'read care': np.int64(1697),
#  'care heart': np.int64(296),
#  'heart feel': np.int64(930),
#  'feel light': np.int64(691),
#  'light someon': np.int64(1160),
#  'someon feel': np.int64(1936),
#  'feel heavi': np.int64(690),
#  'heavi someon': np.int64(933),
#  'someon leav': np.int64(1938),
#  'detail': np.int64(526),
#  'fri': np.int64(753),
#  'wont': np.int64(2423),
#  'doctor': np.int64(552),
#  'hesit': np.int64(939),
#  'second': np.int64(1814),
#  'chang': np.int64(324),
#  'noth': np.int64(1446),
#  'tone': np.int64(2162),
#  'weekli': np.int64(2367),
#  'credit': np.int64(450),
#  'gonna': np.int64(839),
#  'later tonight': np.int64(1123),
#  'ok come': np.int64(1474),
#  'come home': np.int64(391),
#  'nokia': np.int64(1429),
#  'mob': np.int64(1326),
#  'txting': np.int64(2224),
#  'wq': np.int64(2437),
#  'norm': np.int64(1442),
#  'free st': np.int64(746),
#  'st week': np.int64(1976),
#  'week nokia': np.int64(2362),
#  ...}

# %%
from sklearn.naive_bayes import MultinomialNB

t_model = MultinomialNB().fit(x_train_t,y_train)

# %%
y_pred_t = t_model.predict(x_test_t)

# %%
print(classification_report(y_pred_t,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89       143
#            1       1.00      0.96      0.98       972
#
#     accuracy                           0.97      1115
#    macro avg       0.90      0.98      0.93      1115
# weighted avg       0.97      0.97      0.97      1115
